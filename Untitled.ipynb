# %%
import requests
import json
 
url = "http://3.142.121.246:3000/getData?limit=100&skip=0"
 
response = requests.get(url)
print(response)
data = response.text

parsed = json.loads(data)
print(parsed)
# Out:
# <Response [200]>
# ...
