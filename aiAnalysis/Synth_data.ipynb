# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from operator import itemgetter
from csv import writer

# %%
df = pd.read_csv('training_string.csv', sep=',', header=0)
data = df["Acc Z"]
label = df["Labels"]
roi = data[25000:30000]
label_roi = label[25000:30000]
roi
# Out:
# 25000   -0.500000
# 25001   -0.515625
# 25002   -0.484375
# 25003   -0.500000
# 25004   -0.500000
#            ...
# 29588   -0.031250
# 29589   -0.031250
# 29590   -0.031250
# 29591   -0.031250
# 29592   -0.015625
# Name: Acc Z, Length: 4593, dtype: float64

# %%
noise_one = np.random.normal(0,0.03,5000)
noise_two = np.random.normal(0,0.03,5000)
noise_three = np.random.normal(0,0.03,5000)
noise_four = np.random.normal(0,0.03,5000)

plt.figure(figsize=(10,5))
plt.plot(noise_one)
plt.plot(noise_two)
plt.plot(noise_three)
plt.plot(noise_four)
plt.show()

# %%
#plots example of new noise altered data
plt.figure(figsize=(10,5))
plt.plot(original)
plt.show()

plt.figure(figsize=(10,5))
plt.plot(synth_1)
plt.plot(synth_2)
plt.plot(synth_3)
plt.plot(synth_4)
plt.show()
